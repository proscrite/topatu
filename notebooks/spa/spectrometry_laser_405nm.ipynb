# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob

# %%
path = 'C:/Users/IFIc/oceanview'

# %% [markdown]
# # No filter

# %%
file = 'C:/Users/IFIc/oceanview/HR4C10531__0__11-11-16-730.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='No filter')
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'No filter')]

# %%
file = 'C:/Users/IFIc/oceanview/HR4C10531__0__11-11-16-730.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', xlim=(410,500),
              title='No filter')
# Out:
# [Text(0, 0.5, 'counts'),
#  (410, 500),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'No filter')]

# %% [markdown]
# # DMLP reflection

# %%
file = 'C:/Users/IFIc/oceanview/dmlp425_refl_HR4C10531__0__11-42-29-355.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts',
              title='DMLP425_refl')
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'DMLP425_refl')]

# %% [markdown]
# # DMLP Transmission

# %%
file = 'C:/Users/IFIc/oceanview/dmlp425_transm_HR4C10531__0__11-37-55-976.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts',
              title='DMLP425_transmi')
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'DMLP425_transmi')]

# %%
400/16000
# Out:
# 0.025

# %% [markdown]
# ## Combine all scans

# %%
file = 'C:/Users/IFIc/oceanview/dmlp425_transm*'
files = glob.glob(file)


df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='DMLP425_transmi (%i scans)'%len(files), xlim=(410, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  (410, 500),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'DMLP425_transmi (81 scans)')]

# %% [markdown]
# # FBand 420

# %%
file = 'C:/Users/IFIc/oceanview/fband420_HR4C10531__0__11-22-48-044.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts',
              title='FBand 420')
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBand 420')]

# %% [markdown]
# # FBand 430

# %%
file = 'C:/Users/IFIc/oceanview/fband430_HR4C10531__0__11-26-32-827.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts',
              title='FBand 430')
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBand 430')]

# %% [markdown]
# # FBand460

# %%
file = 'C:/Users/IFIc/oceanview/fband460_HR4C10531__0__11-28-18-119.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts',
              title='FBand 460')
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBand 460')]

# %%
file = 'C:/Users/IFIc/oceanview/fband460_HR4C10531__0__11-28-18-119.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', xlim=(430, 500),
              title='FBand 460 ')
# Out:
# [Text(0, 0.5, 'counts'),
#  (430, 500),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBand 460 ')]

# %% [markdown]
# ## Combine all 100 scans

# %%
file = 'C:/Users/IFIc/oceanview/fband460*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='Fband 460(%i scans)'%len(files), xlim=(420, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  (420, 500),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'Fband 460(100 scans)')]

# %% [markdown]
# #  FLong450

# %%
file = 'C:/Users/IFIc/oceanview/flong450_HR4C10531__0__11-31-25-604.txt'
df = pd.read_csv(file, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', xlim=(430, 500),
              title='FLong 450')
# Out:
# [Text(0, 0.5, 'counts'),
#  (430, 500),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FLong 450')]

# %% [markdown]
# ## Combine all files

# %%
file = 'C:/Users/IFIc/oceanview/flong450*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='FLong 450(%i scans)'%len(files), xlim=(440, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  (440, 500),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FLong 450(100 scans)')]

# %% [markdown]
# # AcN emission

# %%
file = 'C:/Users/IFIc/oceanview/FBI_Ba_acn*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='AcN (%i scans)'%len(files))#, xlim=(440, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'AcN (100 scans)')]

# %% [markdown]
# # FBI-Ba

# %%
file = 'C:/Users/IFIc/oceanview/real_FBI_Ba_acn*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='FBI-Ba 1eq. (%i scans)'%len(files))#, xlim=(440, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBI-Ba 1eq. (200 scans)')]

# %%
file = 'C:/Users/IFIc/oceanview/real_FBI_Ba_acn*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='FBI-Ba 1eq. (%i scans)'%len(files), xlim=(410, 550))
# Out:
# [Text(0, 0.5, 'counts'),
#  (410, 550),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBI-Ba 1eq. (200 scans)')]

# %% [markdown]
# # FBI ML in quartz

# %%
file = 'C:/Users/IFIc/oceanview/quartz_window_FBI_monoly_*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='FBI ML in Quartz (%i scans)'%len(files))#, xlim=(440, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'FBI ML in Quartz (6 scans)')]

# %% [markdown]
# # Quartz only

# %%
file = 'C:/Users/IFIc/oceanview/quartz_window_clean_ref*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='Clean Quartz (%i scans)'%len(files))#, xlim=(440, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'Clean Quartz (2 scans)')]

# %% [markdown]
# # Laser no filter 370 mA
#
# At low intensities all modes are emitted, at high power it should lase

# %%
file = 'C:/Users/IFIc/oceanview/Teflon_370*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='Laser high power no filter (%i scans)'%len(files))#, xlim=(440, 500))
# Out:
# [Text(0, 0.5, 'counts'),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'Laser high power no filter (1 scans)')]

# %%
file = 'C:/Users/IFIc/oceanview/Teflon_370*'
files = glob.glob(file)

df = pd.read_csv(files[0], sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
for f in files:
    dfi = pd.read_csv(f, sep='\t', skiprows=14, names=['wavelength', 'counts'], index_col=0)
    df.counts += dfi['counts']
plt.plot(df)
plt.gca().set(xlabel='wavelength [nm]', ylabel='counts', title='Laser high power no filter (%i scans)'%len(files), xlim=(400, 420))
# Out:
# [Text(0, 0.5, 'counts'),
#  (400, 420),
#  Text(0.5, 0, 'wavelength [nm]'),
#  Text(0.5, 1.0, 'Laser high power no filter (1 scans)')]
