# %%
import pylablib.aux_libs.devices.DCAM as cam
from pylablib.aux_libs.devices.DCAM_lib import lib, DCAMLibError

import matplotlib.pyplot as plt
import sys
sys.path.append('C:\\Users\\IFIc\\Projects\\sabatsw\\laserlab\\scripts')
from galvo_python.galvos import *
from galvo_python.gaussian2dFit import *
from time import sleep
import logging
import warnings
from skimage import io

# %%
io.imsave('file0.tif', frame0)

# %%
logging.getLogger().setLevel(logging.CRITICAL)

# %% [markdown]
# ## Initialize camera and galvos

# %%
serialport = open_serial_port()

# %%
cam.get_cameras_number(), cam.DCAMCamera(0).get_model_data()
# Out:
# (1,
#  ModelData(vendor='Hamamatsu', model='C13440-20C', serial_number='S/N: 303065', camera_version='4.31.B'))

# %%
cam0 = cam.DCAMCamera(0)
lib.dcamapi_uninit()     # For some reason this must be run before opening the camera
cam0.open()

min_texp = cam0.properties['EXPOSURE TIME'].min
cam0.set_value('EXPOSURE TIME', min_texp)

cam0.start_acquisition()
cam0.get_status()
# Out:
# 'busy'

# %%
cam0.stop_acquisition()

# %% [markdown]
# #  Take snap

# %%
center0 = [int(65534./2) + 3150, int(65534./2) +  4650] #calibrated on 26/05/2020, normal incidence on galvo

move_to_positionXY(serialport, [0,0], center=center0)

# %%
# %matplotlib inline
plt.style.use('default')
frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

guessNfitGaussian2d(frame, flag_p=True)
# Out:
# [4080.86630647825,
#  564.8890266021832,
#  763.6112001059986,
#  191.85811658455341,
#  0.03448179470785122]

# %%
#LOOP WITH FOR INSTEAD OF WHILE


# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []

frame0 = cam0.get_frame(100)
mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 400)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]

for i in range(0,int(1e2)):
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    
    frame0 = cam0.get_frame(100)
    
    gray = ax1.imshow(frame0)
    fig.colorbar(gray)
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-78-ce084d22ee91> in <module>
#      30     fig.colorbar(gray)
#      31     fig.canvas.draw()
# ---> 32     fig.tight_layout()
#      33     #fig.canvas.update()
#      34     fig.canvas.flush_events()
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in tight_layout(self, renderer, pad, h_pad, w_pad, rect)
#    2474         kwargs = get_tight_layout_figure(
#    2475             self, self.axes, subplotspec_list, renderer,
# -> 2476             pad=pad, h_pad=h_pad, w_pad=w_pad, rect=rect)
#    2477         if kwargs:
#    2478             self.subplots_adjust(**kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in get_tight_layout_figure(fig, axes_list, subplotspec_list, renderer, pad, h_pad, w_pad, rect)
#     360                                      subplot_list=subplot_list,
#     361                                      ax_bbox_list=ax_bbox_list,
# --> 362                                      pad=pad, h_pad=h_pad, w_pad=w_pad)
#     363
#     364     # kwargs can be none if tight_layout fails...
#
# ~\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in auto_adjust_subplotpars(fig, renderer, nrows_ncols, num1num2_list, subplot_list, ax_bbox_list, pad, h_pad, w_pad, rect)
#     109             continue
#     110
# --> 111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
#     112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#
# ~\Anaconda3\lib\site-packages\matplotlib\tight_layout.py in <listcomp>(.0)
#     110
#     111         tight_bbox_raw = union([ax.get_tightbbox(renderer) for ax in subplots
# --> 112                                 if ax.get_visible()])
#     113         tight_bbox = TransformedBbox(tight_bbox_raw,
#     114                                      fig.transFigure.inverted())
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists)
#    4357                 bb.append(bb_xaxis)
#    4358
# -> 4359             bb_yaxis = self.yaxis.get_tightbbox(renderer)
#    4360             if bb_yaxis:
#    4361                 bb.append(bb_yaxis)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_tightbbox(self, renderer)
#    1162         ticks_to_draw = self._update_ticks()
#    1163
# -> 1164         self._update_label_position(renderer)
#    1165
#    1166         # go back to just this axis's tick labels
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2306         # get bounding boxes for this axis and any siblings
#    2307         # that have been set by `fig.align_ylabels()`
# -> 2308         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2309
#    2310         x, y = self.label.get_position()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    2291         for axx in grp.get_siblings(self.axes):
#    2292             ticks_to_draw = axx.yaxis._update_ticks()
# -> 2293             tlb, tlb2 = axx.yaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2294             bboxes.extend(tlb)
#    2295             bboxes2.extend(tlb2)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
#    1149         return ([tick.label1.get_window_extent(renderer)
# -> 1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#    1152                  for tick in ticks if tick.label2.get_visible()])
#
# ~\Anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
# --> 892         x, y = self.get_transform().transform_point((x, y))
#     893         bbox = bbox.translated(x, y)
#     894         if dpi is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform_point(self, point)
#    1479         if len(point) != self.input_dims:
#    1480             raise ValueError("The length of 'point' must be 'self.input_dims'")
# -> 1481         return self.transform(np.asarray([point]))[0]
#    1482
#    1483     def transform_path(self, path):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform(self, values)
#    1392
#    1393         # Transform the values
# -> 1394         res = self.transform_affine(self.transform_non_affine(values))
#    1395
#    1396         # Convert the result back to the shape of the input values.
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in transform_affine(self, points)
#    2371     def transform_affine(self, points):
#    2372         # docstring inherited
# -> 2373         return self.get_affine().transform(points)
#    2374
#    2375     def transform_non_affine(self, points):
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in get_affine(self)
#    2399         else:
#    2400             return Affine2D(np.dot(self._b.get_affine().get_matrix(),
# -> 2401                                 self._a.get_affine().get_matrix()))
#    2402
#    2403     def inverted(self):
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []

frame0 = cam0.get_frame(100)
mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 400)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]

while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    
    frame0 = cam0.get_frame(100)
    
    gray = ax1.imshow(frame0)
    fig.colorbar(gray)
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-e9bd4a63d825> in <module>
#      22     ax1 = fig.add_subplot(3, 1, 1)
#      23
# ---> 24     frame0 = cam0.get_frame(100)
#      25
#      26     gray = ax1.imshow(frame0)
#
# ~\Anaconda3\lib\site-packages\pylablib\aux_libs\devices\DCAM.py in get_frame(self, buffer, return_info)
#     286         Does not advance the read frames counter.
#     287         """
# --> 288         sframe=self._read_buffer(buffer)
#     289         info=self.FrameInfo(sframe.framestamp,sframe.timestamp[0]*10**6+sframe.timestamp[1],sframe.camerastamp,sframe.left,sframe.top,sframe.pixeltype)
#     290         info=tuple(info) if _rpyc else info
#
# ~\Anaconda3\lib\site-packages\pylablib\aux_libs\devices\DCAM.py in _read_buffer(self, buffer)
#     252         self._last_frame=None
#     253     def _read_buffer(self, buffer):
# --> 254         return lib.dcambuf_lockframe(self.handle,buffer)
#     255     @contextlib.contextmanager
#     256     def _reset_buffers(self):
#
# <string> in <lambda>(hdcam, iFrame)
#
# ~\Anaconda3\lib\site-packages\pylablib\core\utils\ctypes_wrap.py in wrapped_func(*args)
#     178             argrvals=[ctypes.byref(rv) if ref else rv for (ref,rv) in zip(rvref,rvals)]
#     179             func_args=self._join_args(iargs,args,irvals,argrvals)
# --> 180             res=func(*func_args)
#     181             rvals=self._conv_rval(rvals,rvconv,args)
#     182             res=self._wrap_rvals(res,rvals,rvnames,return_res)
#
# ~\Anaconda3\lib\site-packages\pylablib\aux_libs\devices\DCAM_lib.py in checker(result, func, arguments)
#      24     """
#      25     passing=set(passing) if passing is not None else set()
# ---> 26     def checker(result, func, arguments):
#      27         if isinstance(result,tuple):
#      28             code,result=result[0],result[1:]
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="1000">

# %% [markdown]
# ## Check reference image size right after galvo

# %%
frameRef = plt.imread("./aligning_4f_052020/nolens_noiris_3cm.tiff")
gray = plt.imshow(frameRef)
plt.colorbar(gray)

bestfit1 = guessNfitGaussian2d(frameRef, flag_p=True)

# %%
xref, yref = bestfit1[1:3]
rRef = bestfit1[3]
rRef
# Out:
# 280.7183325525021

# %% [markdown]
# ## Realigning without lenses, with 2 pinholes

# %% [markdown]
# The procedure is the following:
#
# - Use the first aligning mirror to direct the spot to the center of both galvo mirrors
# - Use the second aligning mirror to focus it through the first pinhole
# - To make the spot pass through the second pinhole, play with the second aligning mirror, the rotation of the galvos (not the position, just for large adjustment) and the origin of the galvos rotation (center0) for fine tuning.

# %% [markdown]
# # Find lens 2 focus and center

# %% [markdown]
# ## Center

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    fig = plt.gcf()
    ax1 = fig.add_subplot(1, 1, 1)
    
    frame0 = cam0.get_frame(100)

    img = ax1.imshow(frame0)
    fig.colorbar(img)
    mx = guess_centroid(frame0)

    ax1.scatter(x=xref, y=yref, marker='x',
     color='g', label = 'Ref: (%.1f, %.1f)' %(xref, yref))
    
    ax1.scatter(x=mx[1], y=mx[0], marker='x',
     color='r', label = '(%.1f, %.1f)' %(mx[0], mx[1]))
    ax1.legend()

    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    plt.clf()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-fe17359acad3> in <module>
#      12     frame0 = cam0.get_frame(100)
#      13
# ---> 14     img = ax1.imshow(frame0)
#      15     fig.colorbar(img)
#      16     mx = guess_centroid(frame0)
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5669                               resample=resample, **kwargs)
#    5670
# -> 5671         im.set_data(X)
#    5672         im.set_alpha(alpha)
#    5673         if im.get_clip_path() is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     678             if isinstance(A, Image.Image):
#     679                 A = pil_to_array(A)  # Needed e.g. to apply png palette.
# --> 680         self._A = cbook.safe_masked_invalid(A, copy=True)
#     681
#     682         if (self._A.dtype != np.uint8 and
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in safe_masked_invalid(x, copy)
#     802
#     803     try:
# --> 804         xm = np.ma.masked_invalid(x, copy=False)
#     805         xm.shrink_mask()
#     806     except TypeError:
#
# ~\Anaconda3\lib\site-packages\numpy\ma\core.py in masked_invalid(a, copy)
#    2364         cls = type(a)
#    2365     else:
# -> 2366         condition = ~(np.isfinite(a))
#    2367         cls = MaskedArray
#    2368     result = a.view(cls)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Focus z

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []

frame0 = cam0.get_frame(100)
mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 400)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]

while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)

    frame0 = cam0.get_frame(100)
    
    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 400)
    imroi = select_roi(frame0, bounds)
    try:
        fit = fitGauss2d(imroi, p0 = p0)
        pars = make_params(fit);
        if (pars[3] > 0 ) and (pars[3] < 200):
            sx.append(pars[3])
        ax2.plot(sx, label='$w$')
        #ax2.set_ylim(15, 25)
        ax2.legend()
    
    except RuntimeError:
        pass
    
    pars = zoom_out(pars, bounds)
    plot_fit_result(frame0, pars, ax=ax1);
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="NaN">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-ff4b1645bb8e> in <module>
#      29     imroi = select_roi(frame0, bounds)
#      30     try:
# ---> 31         fit = fitGauss2d(imroi, p0 = p0)
#      32         pars = make_params(fit);
#      33         if (pars[3] > 0 ) and (pars[3] < 200):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in fitGauss2d(im, p0, mode)
#      93     initial.add("background",value=0)
#      94
# ---> 95     fit = minimize(residuals, initial, args=(xx, yy, im, mode))#, method='cg')
#      96     return fit
#      97
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2391                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2392                        calc_covar=calc_covar, **fit_kws)
# -> 2393     return fitter.minimize(method=method)
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2174                         val.lower().startswith(user_method)):
#    2175                     kwargs['method'] = val
# -> 2176         return function(**kwargs)
#    2177
#    2178
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1566
#    1567         try:
# -> 1568             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1569         except AbortFitException:
#    1570             pass
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     394             maxfev = 200*(n + 1)
#     395         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 396                                  gtol, maxfev, epsfcn, factor, diag)
#     397     else:
#     398         if col_deriv:
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     513
#     514         """
# --> 515         params = self.result.params
#     516
#     517         if fvars.shape == ():
#
# KeyboardInterrupt:

# %% [markdown]
# ##### With strictly normal incidence on the galvo, the focus distance is the actual one (40 cm)
#
# The waist in the focus is w = 8.7 px

# %% [markdown]
# # Find lens 1 position and center

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    fig = plt.gcf()
    ax1 = fig.add_subplot(1, 1, 1)
    
    frame0 = cam0.get_frame(100)

    img = ax1.imshow(frame0)
    fig.colorbar(img)
    mx = guess_centroid(frame0)

    ax1.scatter(x=xref, y=yref, marker='x',
     color='g', label = 'Ref: (%.1f, %.1f)' %(xref, yref))
    
    ax1.scatter(x=mx[1], y=mx[0], marker='x',
     color='r', label = '(%.1f, %.1f)' %(mx[0], mx[1]))
    ax1.legend()

    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    plt.clf()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-fe17359acad3> in <module>
#      27     #fig.canvas.update()
#      28     fig.canvas.flush_events()
# ---> 29     plt.clf()
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in clf()
#     696 def clf():
#     697     """Clear the current figure."""
# --> 698     gcf().clf()
#     699
#     700
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in clf(self, keep_observers)
#    1633
#    1634         for ax in tuple(self.axes):  # Iterate over the copy.
# -> 1635             ax.cla()
#    1636             self.delaxes(ax)         # removes ax from self._axstack
#    1637
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in cla(self)
#     975
#     976         for name, spine in self.spines.items():
# --> 977             spine.cla()
#     978
#     979         self.ignore_existing_data_limits = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\spines.py in cla(self)
#     228         self._position = None  # clear position
#     229         if self.axis is not None:
# --> 230             self.axis.cla()
#     231
#     232     @cbook.deprecated("3.1")
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in cla(self)
#     833                              rcParams['axes.grid.which'] in ('both', 'minor'))
#     834
# --> 835         self.reset_ticks()
#     836
#     837         self.converter = None
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in reset_ticks(self)
#     856             pass
#     857         try:
# --> 858             self.set_clip_path(self.axes.patch)
#     859         except AttributeError:
#     860             pass
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in set_clip_path(self, clippath, transform)
#     945     def set_clip_path(self, clippath, transform=None):
#     946         martist.Artist.set_clip_path(self, clippath, transform)
# --> 947         for child in self.majorTicks + self.minorTicks:
#     948             child.set_clip_path(clippath, transform)
#     949         self.stale = True
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in __get__(self, instance, cls)
#     667             if self._major:
#     668                 instance.majorTicks = []
# --> 669                 tick = instance._get_tick(major=True)
#     670                 instance.majorTicks.append(tick)
#     671                 return instance.majorTicks
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick(self, major)
#    1931         else:
#    1932             tick_kw = self._minor_tick_kw
# -> 1933         return XTick(self.axes, 0, '', major=major, **tick_kw)
#    1934
#    1935     def _get_label(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in __init__(self, axes, loc, label, size, width, color, tickdir, pad, labelsize, labelcolor, zorder, gridOn, tick1On, tick2On, label1On, label2On, major, labelrotation, grid_color, grid_linestyle, grid_linewidth, grid_alpha, **kw)
#     156         self.apply_tickdir(tickdir)
#     157
# --> 158         self.tick1line = self._get_tick1line()
#     159         self.tick2line = self._get_tick2line()
#     160         self.gridline = self._get_gridline()
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _get_tick1line(self)
#     462                           linestyle='None', marker=self._tickmarkers[0],
#     463                           markersize=self._size,
# --> 464                           markeredgewidth=self._width, zorder=self._zorder)
#     465         l.set_transform(self.axes.get_xaxis_transform(which='tick1'))
#     466         self._set_artist_props(l)
#
# ~\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     380         self._color = None
#     381         self.set_color(color)
# --> 382         self._marker = MarkerStyle(marker, fillstyle)
#     383
#     384         self._markevery = None
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     767
#     768     def _set_tickdown(self):
# --> 769         self._transform = Affine2D().scale(1.0, -1.0)
#     770         self._snap_threshold = 1.0
#     771         self._filled = False
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,10))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []
while True:
    fig = plt.gcf()
    ax1 = fig.add_subplot(1, 1, 1)
    
    frame0 = cam0.get_frame(100)

    img = ax1.imshow(frame0)
    fig.colorbar(img)
    mx = guess_centroid(frame0)
 
    ax1.scatter(x=xref, y=yref, marker='x',
     color='g', label = 'Ref: (%.1f, %.1f)' %(xref, yref))

    circleRef = plt.Circle((xref, yref), radius=rRef, color='g', lw=1, fill=False,
     label = '$\omega = $ %.1f' %rRef)
    ax1.add_artist(circleRef)
    
    bounds = bound_roi(frame0, mx, size = 400)
    imroi = select_roi(frame0, bounds)
    mxroi = guess_centroid(imroi)

    try:
        fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
        sigma_x = fitc[2]
        sigma_y = fitr[2]
        p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
        fit = fitGauss2d(imroi, p0 = p0)
        pars = make_params(fit);
        p0 = zoom_out(pars, bounds)

    except RuntimeError:
        pass
    
    ax1.scatter(x=p0[1], y=p0[2], marker='x',
     color='r', label = '(%.1f, %.1f)' %(mx[1], mx[0])) 
    
    circle = plt.Circle((p0[1], p0[2]), radius=p0[3], color='r', lw=1, fill=False,
     label = '$\omega, = $ %.1f' %p0[3])
    
#    plot_fit_result(frame0, pars, ax=ax1);
    ax1.add_artist(circle)
    ax1.legend()
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    plt.clf()
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-a847a955c027> in <module>
#      32         sigma_y = fitr[2]
#      33         p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
# ---> 34         fit = fitGauss2d(imroi, p0 = p0)
#      35         pars = make_params(fit);
#      36         p0 = zoom_out(pars, bounds)
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in fitGauss2d(im, p0, mode)
#      93     initial.add("background",value=0)
#      94
# ---> 95     fit = minimize(residuals, initial, args=(xx, yy, im, mode))#, method='cg')
#      96     return fit
#      97
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2391                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2392                        calc_covar=calc_covar, **fit_kws)
# -> 2393     return fitter.minimize(method=method)
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2174                         val.lower().startswith(user_method)):
#    2175                     kwargs['method'] = val
# -> 2176         return function(**kwargs)
#    2177
#    2178
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1566
#    1567         try:
# -> 1568             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1569         except AbortFitException:
#    1570             pass
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     394             maxfev = 200*(n + 1)
#     395         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 396                                  gtol, maxfev, epsfcn, factor, diag)
#     397     else:
#     398         if col_deriv:
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     513
#     514         """
# --> 515         params = self.result.params
#     516
#     517         if fvars.shape == ():
#
# KeyboardInterrupt:

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []

frame0 = cam0.get_frame(100)
mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 400)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]

while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)

    frame0 = cam0.get_frame(100)
    
    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 400)
    imroi = select_roi(frame0, bounds)
    try:
        fit = fitGauss2d(imroi, p0 = p0)
        pars = make_params(fit);
        if (pars[3] > 0 ) and (pars[3] < 300):
            sx.append(pars[3])
        ax2.plot(sx, label='$w$')
        #ax2.set_ylim(15, 25)
        ax2.legend()
    
    except RuntimeError:
        pass
    
    pars = zoom_out(pars, bounds)
    plot_fit_result(frame0, pars, ax=ax1);
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-a37c063dcc4c> in <module>
#      29     imroi = select_roi(frame0, bounds)
#      30     try:
# ---> 31         fit = fitGauss2d(imroi, p0 = p0)
#      32         pars = make_params(fit);
#      33         if (pars[3] > 0 ) and (pars[3] < 300):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in fitGauss2d(im, p0, mode)
#      93     initial.add("background",value=0)
#      94
# ---> 95     fit = minimize(residuals, initial, args=(xx, yy, im, mode))#, method='cg')
#      96     return fit
#      97
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2391                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2392                        calc_covar=calc_covar, **fit_kws)
# -> 2393     return fitter.minimize(method=method)
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2174                         val.lower().startswith(user_method)):
#    2175                     kwargs['method'] = val
# -> 2176         return function(**kwargs)
#    2177
#    2178
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1566
#    1567         try:
# -> 1568             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1569         except AbortFitException:
#    1570             pass
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     394             maxfev = 200*(n + 1)
#     395         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 396                                  gtol, maxfev, epsfcn, factor, diag)
#     397     else:
#     398         if col_deriv:
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     528         self.result.nfev += 1
#     529
# --> 530         out = self.userfcn(params, *self.userargs, **self.userkws)
#     531
#     532         if callable(self.iter_cb):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in residuals(p, x, y, z, mode)
#      77         return (z - height*gaussian2D(x,y,
#      78                                       cen_x, cen_y, sigma_x, sigma_y, offset)) if mode == 'ind'  else (z - height*gaussian2DWaist(x,y,
# ---> 79                                                                                                                 cen_x, cen_y, w, offset))
#      80     initial = Parameters()
#      81     initial.add("height",value=p0[0])
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in gaussian2DWaist(x, y, cen_x, cen_y, w, offset)
#      63     def gaussian2DWaist(x, y, cen_x, cen_y, w, offset):
#      64         """Gaussian beam intensity, waist parametrization"""
# ---> 65         return np.exp(-2.0*((cen_x-x)**2 + (cen_y-y)**2)/w**2) + offset
#      66
#      67     def residuals(p, x, y, z, mode: str = mode):
#
# KeyboardInterrupt:

# %%
frame0 = cam0.get_frame(100)
mx = guess_centroid(frame0)

ax1.add_artist(circleRef)

bounds = bound_roi(frame0, mx, size = 400)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)


fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]
fit = fitGauss2d(imroi, p0 = p0)
pars = make_params(fit);
p0 = zoom_out(pars, bounds)

# %%
p0[3], rRef
# Out:
# (280.11309598101514, 280.7183325525021)

# %% [markdown]
# ##### The distance 2f is now 80 cm as it should be
# Waist size conserved up to 1 px

# %% [markdown]
# # Find distance z to galvo: move mirrors and check image stays put

# %%
p1 = [-1800, 0] # p1
p2 = [-3100, 0] # p2
p3 = [-4800, 0] # p3
p0 = [0,0]
p4 = [+1500, 0] # p4
p5 = [+3000, 0] # p5
p6 = [+900, 0] # p6
p7 = [-800, 0] # p7

r1 = [0, 600] # r1
r2 = [0, 1500] # r2
r3 = [0, -800] # r1
r4 = [0, -1500] # r1

hpoints = [p4, p6, p0, p7, p1, p2]
vpoints = [r2, r1, p0, r3, r4]

for hp in vpoints:
    move_to_positionXY(serialport, position=hp, center=center0, wait=3)

# %%
for hp in hpoints:
    move_to_positionXY(serialport, position=hp, center=center0, wait=0.1)
    
for hp in vpoints:
    move_to_positionXY(serialport, position=hp, center=center0, wait=0.1)

# %%
move_to_positionXY(serialport, position=hpoints[2], center=center0, wait=3)

# %%
fitsV, fitsH = [], []

# %% [markdown]
# ## Move every component 12.5 mm further, z = 412.5 mm

# %% [markdown]
# ##### So L1 and CAM at 24, L2 at 0 mm

# %%
# %matplotlib inline
fitsh = []
for hp in hpoints:
    move_to_positionXY(serialport, position=hp, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(frameh, flag_p=False)
    fitsh.append(bestfit1)
    
    plot_fit_result(frameh, bestfit1)
    
    print(bestfit1[1:3])
    sleep(3)
fitsH.append(fitsh)
# Out:
# [334.29470112656014, 1655.6828326607265]
# [544.273275860513, 1643.1690522161114]
# [865.4509405523496, 1651.231672914102]
# [1131.397488383111, 1670.8501358901467]
# [490.474570296454, 1109.0131433668291]
# [491.2196034724218, 878.4089983633291]

# %%
# %matplotlib inline
fitsv = []
for vp in vpoints:
    move_to_positionXY(serialport, position=vp, center=center0)
    sleep(1)
    
    framev = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(framev, flag_p=False)
    fitsv.append(bestfit1)
    
    plot_fit_result(framev, bestfit1)

    print(bestfit1[1:3])
    sleep(3)
fitsV.append(fitsv)
# Out:
# [484.79717619097465, 737.5344761921205]
# [843.9967616081519, 1986.3224251174024]
# [859.5672243384946, 1645.7039025005888]
# [854.7268799596555, 1199.5087102779148]
# [856.9411384939317, 776.901948404395]

# %% [markdown]
# ## Displacer center, z = 400 mm

# %% [markdown]
# ##### Every component displacer scale on 12.5 mm (scale center)

# %%
# %matplotlib inline
fitsh = []
for hp in hpoints:
    move_to_positionXY(serialport, position=hp, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(frameh, flag_p=False)
    fitsh.append(bestfit1)
    
    plot_fit_result(frameh, bestfit1)
    print(bestfit1[1:3])
    sleep(3)
fitsH.append(fitsh)
# Out:
# [338.9874849688149, 1648.9193794857638]
# [537.112667091528, 1670.1127240604428]
# [856.520883802539, 1677.6090357968026]
# [1132.039370844984, 1673.6928879151924]
# [525.0273245877997, 793.4085216900426]
# [501.34504207149723, 940.4949793888297]

# %%
# %matplotlib inline
fitsv = []
for vp in vpoints:
    move_to_positionXY(serialport, position=vp, center=center0)
    sleep(1)
    
    framev = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(framev, flag_p=False)
    fitsv.append(bestfit1)
    
    plot_fit_result(framev, bestfit1)
    print(bestfit1[1:3])
    sleep(3)
fitsV.append(fitsv)
# Out:
# [505.58127933054476, 945.5999495011479]
# [841.567061520185, 1999.8386689140284]
# [854.4568238768161, 1659.7608976584488]
# [866.1626039496316, 1195.167092721404]
# [880.4201965279101, 819.9243716000154]

# %% [markdown]
# ## Plot results

# %%
z = [425, 400, 395, 393, 391, 387.5, 387.5, 385, 382.5, 380, 377.5, 375]

sizesV = [np.matrix(f)[1, 3] - np.matrix(f)[2,3] for f in fitsV]
sizesH = [np.matrix(f)[1, 3] - np.matrix(f)[2,3] for f in fitsH]

dy1  = [np.std(np.matrix(f)[:,2]) for f in fitsV]
dx1  = [np.std(np.matrix(f)[:,1]) for f in fitsH]

plt.style.use('default')
#plt.plot(z, sizesH, 'X', label='$w_H$')
#plt.plot(z, sizesV, 'X', label='$w_V$')

plt.plot(z, dx1, 'o', label='$\Delta x_1$')
plt.plot(z, dy1, 'o', label='$\Delta y_1$')

plt.legend()

# %%
sizesV = [np.matrix(f)[1, 3] - np.matrix(f)[2,3] for f in fitsV]
sizesH = [np.matrix(f)[1, 3] - np.matrix(f)[2,3] for f in fitsH]

dy1 = [np.matrix(f)[1, 2] - np.matrix(f)[2,2] for f in fitsV]
dx1 = [np.matrix(f)[1, 1] - np.matrix(f)[2,1] for f in fitsH]

dy2 = [np.matrix(f)[3, 2] - np.matrix(f)[2,2] for f in fitsV]
dx2 = [np.matrix(f)[3, 1] - np.matrix(f)[2,1] for f in fitsH]


plt.style.use('default')
plt.plot(z, sizesH, 'X', label='$w_H$')
plt.plot(z, sizesV, 'X', label='$w_V$')

plt.plot(z, dx1, 'o', label='$\Delta x_1$')
plt.plot(z, dy1, 'o', label='$\Delta y_1$')

#plt.plot(z, dx2, 'o', label='$\Delta x_2$')
#plt.plot(z, dy2, 'o', label='$\Delta y_2$')
plt.legend()

# %%
sizesV = [np.matrix(f)[1, 3] for f in fitsV]
sizesH = [np.matrix(f)[1, 3] for f in fitsH]


plt.style.use('default')
plt.plot(z, sizesH, 'X', label='$w_H$')
plt.plot(z, sizesV, 'X', label='$w_V$')


plt.legend()

# %%
rRef
# Out:
# 280.7183325525021

# %%
fitsv[-1][3]
# Out:
# 278.62181566838734

# %% [markdown]
# # Now back on L1, CAM 0 25, move L2

# %%
rmax = [(0,0), (0, 2500), (0,-2800), (-4200, 0), (4200, 0)]
rhalf = [(0, 1250), (0, -1400), (-2100, 0), (2100, 0)]

# %%
fitsV2, fitsH2 = [], []

# %% [markdown]
# ## OB = 25mm

# %%
# %matplotlib inline
fig, ax = plt.subplots(1)
plt.style.use('dark_background')
fitsh = []
for i in rmax+rhalf:
    move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    ax.imshow(frameh)
    bestfit1 = guess_centroid(frameh)
    fitsh.append([bestfit1[1], bestfit1[0], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity
    
    cross = ax.scatter(x=bestfit1[0], y=bestfit1[1], marker='x',
                       color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
    ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
    print(bestfit1)
fitsH2.append(fitsh)
# Out:
# (651, 1021)
# (440, 1030)
# (981, 1011)
# (648, 1431)
# (681, 603)
# (525, 1023)
# (860, 973)
# (651, 1219)
# (652, 828)

# %% [markdown]
# ## OB = 23mm

# %%
# %matplotlib inline
fig, ax = plt.subplots(1)
plt.style.use('dark_background')
fitsh = []
for i in rmax+rhalf:
    move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    ax.imshow(frameh)
    bestfit1 = guess_centroid(frameh)
    fitsh.append([bestfit1[1], bestfit1[0], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity
    
    cross = ax.scatter(x=bestfit1[0], y=bestfit1[1], marker='x',
                       color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
    ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
    print(bestfit1)
fitsH2.append(fitsh)
# Out:
# (651, 749)
# (443, 756)
# (980, 738)
# (649, 1155)
# (686, 340)
# (527, 748)
# (860, 699)
# (650, 945)
# (653, 556)

# %% [markdown]
# ## OB = 21mm

# %%
# %matplotlib inline
fig, ax = plt.subplots(1)
plt.style.use('dark_background')
fitsh = []
for i in rmax+rhalf:
    move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    ax.imshow(frameh)
    bestfit1 = guess_centroid(frameh)
    fitsh.append([bestfit1[1], bestfit1[0], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity
    
    cross = ax.scatter(x=bestfit1[0], y=bestfit1[1], marker='x',
                       color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
    ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
    print(bestfit1)
fitsH2.append(fitsh)
# Out:
# (653, 750)
# (403, 749)
# (958, 722)
# (651, 1139)
# (659, 361)
# (534, 750)
# (783, 747)
# (653, 937)
# (724, 509)

# %%
## OB = 19mm

# %%
# %matplotlib inline
fig, ax = plt.subplots(1)
plt.style.use('dark_background')
fitsh = []
for i in rmax+rhalf:
    move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    ax.imshow(frameh)
    bestfit1 = guess_centroid(frameh)
    fitsh.append([bestfit1[1], bestfit1[0], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity
    
    cross = ax.scatter(x=bestfit1[0], y=bestfit1[1], marker='x',
                       color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
    ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
    print(bestfit1)
fitsH2.append(fitsh)
# Out:
# (653, 750)
# (403, 749)
# (958, 722)
# (651, 1139)
# (659, 361)
# (534, 750)
# (783, 747)
# (653, 937)
# (724, 509)

# %% [markdown]
# ## L2 = 3mm, L1 = 27 mm

# %%
# %matplotlib inline
fitsh = []
for hp in hpoints:
    move_to_positionXY(serialport, position=hp, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(frameh, flag_p=False)
    fitsh.append(bestfit1)
    
    plot_fit_result(frameh, bestfit1)
    print(bestfit1[1:3])
fitsH2.append(fitsh)
# Out:
# [1082.492752985267, 1004.5156948662793]
# [1052.615314110934, 1007.8226913300562]
# [1020.148379259046, 1011.1923094043591]
# [993.150572572333, 1005.6983157506011]
# [955.2232309084632, 1010.8716058882055]
# [902.2228915076897, 1013.1622652761966]

# %%
# %matplotlib inline
fitsv = []
for vp in vpoints:
    move_to_positionXY(serialport, position=vp, center=center0)
    sleep(1)
    
    framev = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(framev, flag_p=False)
    fitsv.append(bestfit1)
    
    plot_fit_result(framev, bestfit1)
    print(bestfit1[1:3])
fitsV2.append(fitsv)
# Out:
# [1021.7677574794368, 999.4690778038685]
# [1026.2894730313953, 1001.235227980773]
# [1020.1897543575103, 1011.5053131618104]
# [1025.251543568504, 1009.6741902897098]
# [1025.5768759108728, 1015.9799006221155]

# %%
np.matrix(fitsH2[0])[1,0]
# Out:
# 1171

# %%
fitsH2
# Out:
# [[[1174, 1004, 14770],
#   [1171, 792, 65535],
#   [1169, 1233, 11429],
#   [1384, 988, 65535],
#   [946, 1005, 19905],
#   [1169, 923, 7985],
#   [1170, 1116, 10992],
#   [1265, 1004, 27512],
#   [1061, 1004, 13343]],
#  [[1151, 1005, 17070],
#   [1164, 794, 65535],
#   [1147, 1235, 15266],
#   [1374, 986, 65535],
#   [935, 1011, 65535],
#   [1142, 921, 11862],
#   [1149, 1119, 15269],
#   [1245, 1008, 54975],
#   [1040, 1007, 41138]]]

# %%
z = [25, 23, 21]

dx1 = [np.matrix(f)[5, 0] - np.matrix(f)[0,0] for f in fitsH2]
dy1 = [np.matrix(f)[5, 1] - np.matrix(f)[0,1] for f in fitsH2]
dx2 = [np.matrix(f)[7, 0] - np.matrix(f)[0,0] for f in fitsH2]
dy2 = [np.matrix(f)[7, 1] - np.matrix(f)[0,1] for f in fitsH2]

plt.style.use('default')
plt.plot(z, dy1, 'X', label='$w_H$')
plt.plot(z, dx1, 'X', label='$w_V$')

plt.plot(z, dx2, 'o', label='$\Delta x_1$')
plt.plot(z, dy2, 'o', label='$\Delta y_1$')

plt.legend()

# %%
z = [25, 23, 21]

dx1 = [np.std(np.matrix(f)[:, 0]) for f in fitsH2]
dy1 = [np.std(np.matrix(f)[:, 1]) for f in fitsH2]

plt.style.use('default')
plt.plot(z, dy1, 'X', label='$w_H$')
plt.plot(z, dx1, 'X', label='$w_V$')

plt.legend()

# %% [markdown]
# ## Try with same galvo shifts in x and y (not fair to compare otherwise)

# %%
p1 = [-1500, 0] # p1
p0 = [0,0]
p4 = [+1500, 0] # p4
p6 = [+750, 0] # p6
p7 = [-750, 0] # p7

r1 = [0, 750] # r1
r2 = [0, 1500] # r2
r3 = [0, -750] # r1
r4 = [0, -1500] # r1

hpoints = [p4, p6, p0, p7, p1]
vpoints = [r2, r1, p0, r3, r4]

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-172-c8ec22b3e787> in <module>
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %%
# %matplotlib inline
fitsh = []
for hp in hpoints:
    move_to_positionXY(serialport, position=hp, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(frameh, flag_p=False)
    fitsh.append(bestfit1)
    
    plot_fit_result(frameh, bestfit1)
    print(bestfit1[1:3])
fitsH2.append(fitsh)
# Out:
# [1389.4853672060744, 1014.9277201587491]
# [1363.5932020762207, 1014.8796293509059]
# [1338.985010161009, 1014.8124204379701]
# [1314.2643496181222, 1014.6865582573895]
# [1288.974272841901, 1014.6441549143769]

# %%
# %matplotlib inline
fitsv = []
for vp in vpoints:
    move_to_positionXY(serialport, position=vp, center=center0)
    sleep(1)
    
    framev = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(framev, flag_p=False)
    fitsv.append(bestfit1)
    
    plot_fit_result(framev, bestfit1)
    print(bestfit1[1:3])
fitsV2.append(fitsv)
# Out:
# [1337.3291386486408, 1011.9202353540272]
# [1338.5020325740604, 1014.6374858857727]
# [1338.8007786451872, 1014.9647578966983]
# [1339.0916557768285, 1015.3166319799903]
# [1340.1030252950313, 1018.3405825117541]

# %%
np.arctan(3/370)
# Out:
# 0.008107930435610665

# %% [markdown]
# # Try with microscope objective

# %%
move_to_positionXY(serialport, position=(0, 0), center=center0)

# %%
for i in range(20):
    for i in range(-3000, 3000, 100):
        move_to_positionXY(serialport, position=(0,i), center=center0, wait=0.01)

# %%
for i in range(-5000, 5000, 100):
    move_to_positionXY(serialport, position=(i, 0), center=center0, wait=0.1)

# %%
move_to_positionXY(serialport, position=hpoints[2], center=center0)

# %% [markdown]
# ###### Covering the whole diameter of the lens 1, after the objective the beam moves about 1 mm

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
sx, sy = [], []

frame0 = cam0.get_frame(100)
mx = guess_centroid(frame0)
bounds = bound_roi(frame0, mx, size = 400)
imroi = select_roi(frame0, bounds)
mxroi = guess_centroid(imroi)
fitr, fitc = fitGausRowCol(imroi, mxroi, flag_p=False)
sigma_x = fitc[2]
sigma_y = fitr[2]
p0 = [imroi.max(), mxroi[1], mxroi[0], sigma_x, sigma_y]

while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(3, 1, 1)
    ax2 = fig.add_subplot(3, 1, 2)

    frame0 = cam0.get_frame(100)
    
    mx = guess_centroid(frame0)
    bounds = bound_roi(frame0, mx, size = 400)
    imroi = select_roi(frame0, bounds)
    try:
        fit = fitGauss2d(imroi, p0 = p0)
        pars = make_params(fit);
        if (pars[3] > 0 ) and (pars[3] < 200):
            sx.append(pars[3])
        ax2.plot(sx, label='$w$')
        #ax2.set_ylim(15, 25)
        ax2.legend()
    
    except RuntimeError:
        pass
    
    pars = zoom_out(pars, bounds)
    plot_fit_result(frame0, pars, ax=ax1);
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="1000">
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-737-ff4b1645bb8e> in <module>
#      29     imroi = select_roi(frame0, bounds)
#      30     try:
# ---> 31         fit = fitGauss2d(imroi, p0 = p0)
#      32         pars = make_params(fit);
#      33         if (pars[3] > 0 ) and (pars[3] < 200):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in fitGauss2d(im, p0, mode)
#      93     initial.add("background",value=0)
#      94
# ---> 95     fit = minimize(residuals, initial, args=(xx, yy, im, mode))#, method='cg')
#      96     return fit
#      97
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(fcn, params, method, args, kws, iter_cb, scale_covar, nan_policy, reduce_fcn, calc_covar, **fit_kws)
#    2391                        nan_policy=nan_policy, reduce_fcn=reduce_fcn,
#    2392                        calc_covar=calc_covar, **fit_kws)
# -> 2393     return fitter.minimize(method=method)
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in minimize(self, method, params, **kws)
#    2174                         val.lower().startswith(user_method)):
#    2175                     kwargs['method'] = val
# -> 2176         return function(**kwargs)
#    2177
#    2178
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in leastsq(self, params, **kws)
#    1566
#    1567         try:
# -> 1568             lsout = scipy_leastsq(self.__residual, variables, **lskws)
#    1569         except AbortFitException:
#    1570             pass
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\minpack.py in leastsq(func, x0, args, Dfun, full_output, col_deriv, ftol, xtol, gtol, maxfev, epsfcn, factor, diag)
#     394             maxfev = 200*(n + 1)
#     395         retval = _minpack._lmdif(func, x0, args, full_output, ftol, xtol,
# --> 396                                  gtol, maxfev, epsfcn, factor, diag)
#     397     else:
#     398         if col_deriv:
#
# ~\Anaconda3\lib\site-packages\lmfit\minimizer.py in __residual(self, fvars, apply_bounds_transformation)
#     528         self.result.nfev += 1
#     529
# --> 530         out = self.userfcn(params, *self.userargs, **self.userkws)
#     531
#     532         if callable(self.iter_cb):
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in residuals(p, x, y, z, mode)
#      77         return (z - height*gaussian2D(x,y,
#      78                                       cen_x, cen_y, sigma_x, sigma_y, offset)) if mode == 'ind'  else (z - height*gaussian2DWaist(x,y,
# ---> 79                                                                                                                 cen_x, cen_y, w, offset))
#      80     initial = Parameters()
#      81     initial.add("height",value=p0[0])
#
# ~\Projects\sabatsw\laserlab\scripts\galvo_python\gaussian2dFit.py in gaussian2DWaist(x, y, cen_x, cen_y, w, offset)
#      63     def gaussian2DWaist(x, y, cen_x, cen_y, w, offset):
#      64         """Gaussian beam intensity, waist parametrization"""
# ---> 65         return np.exp(-2.0*((cen_x-x)**2 + (cen_y-y)**2)/w**2) + offset
#      66
#      67     def residuals(p, x, y, z, mode: str = mode):
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib inline
plt.style.use('default')
frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

guessNfitGaussian2d(frame, flag_p=True)
# Out:
# [88226.16632183695,
#  1159.3085846483298,
#  970.972624136498,
#  7.54652648951606,
#  0.0011435250159100398]

# %%
io.imsave('objective_focus_4f.tiff', frame0)
# Out:
# C:\Users\IFIc\Anaconda3\lib\site-packages\skimage\io\_io.py:141: UserWarning: objective_focus_4f.tiff is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %% [markdown]
# ## Measure displacements along the whole lens diameter

# %%
fitsHo = []

# %%
rmax = [(0,0), (0, 2500), (0,-2800), (-4200, 0), (4200, 0)]
rhalf = [(0, 1250), (0, -1400), (-2100, 0), (2100, 0)]

# %%
rreal = np.array([18, 22, 22, 20, 10, 10, 10, 10])
beta1 = np.arctan(rreal/400)
beta1
# Out:
# array([0.04496966, 0.05494464, 0.05494464, 0.0499584 , 0.02499479,
#        0.02499479, 0.02499479, 0.02499479])

# %% [markdown]
# ### Plot results

# %%
zs = [0, 5, 10, 15, 16.5, 18, 20, 21.5, 22.5, 23.5, 25, 27]

# %%
#zs = np.arange(0, len(fitsHo), dtype=float) *5
px = 6.5e-3  # Pixel size
betaRatioAv = []
intAv = []
for zi in range(len(zs)): # zi iterates over positions in z
    r0 = np.array(fitsHo[zi])[0,:2]
    betaRatio = []
    for pi in range(1,3): # 9 points each zi
        r = np.sqrt((np.matrix(fitsHo[zi])[pi,0]-r0[0])**2 + (np.matrix(fitsHo[zi])[pi,1]-r0[1])**2)
        beta2 = np.arctan(r * px / 30)
        betaRatio.append(beta2/beta1[pi-1])
    betaRatioAv.append((np.average(betaRatio), np.std(betaRatio)))
    intAv.append((np.average(np.matrix(fitsHo[zi])[1:,2]), np.std(np.matrix(fitsHo[zi])[1:,2])))

intAv = np.matrix(intAv)
betaRatios = np.matrix(betaRatioAv)

# %%
plt.style.use('default')

plt.errorbar(x=zs, y=betaRatios[:,0], yerr=betaRatios[:,1], fmt='o')
plt.xlabel('z position')
plt.ylabel('$\\beta_2/\\beta_1$')
# Out:
# C:\Users\IFIc\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0, 0.5, '$\\beta_2/\\beta_1$')

# %%
plt.style.use('default')

plt.errorbar(x=zs, y=intAv[:,0], yerr=intAv[:,1], fmt='o')
plt.xlabel('z position')
plt.ylabel('Avg intensity')
# Out:
# C:\Users\IFIc\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Support for passing a (n, 1)-shaped error array to errorbar() is deprecated since Matplotlib 3.1 and will be removed in 3.3; pass a 1D array instead.
#   This is separate from the ipykernel package so we can avoid doing imports until
# Text(0, 0.5, 'Avg intensity')

# %%
intAv[:,1]
# Out:
# matrix([[ 678.16986027],
#         [ 902.4364157 ],
#         [1252.3127355 ],
#         [1276.45681478],
#         [1232.27287461],
#         [1166.10162507],
#         [ 879.40249602],
#         [1057.18694391],
#         [1114.06748421],
#         [1479.37740283],
#         [1461.56734685],
#         [ 946.59263116]])

# %% [markdown]
# ## Scan and fit whole grid

# %% [markdown]
# ##### zOb = 10 mm, zCAM = 15 mm

# %% [markdown]
# ### Check intensity variation without moving galvos

# %%
move_to_positionXY(serialport, position=[0,0], center=center0)

# %%
# %matplotlib inline
plt.style.use('dark_background')
fig, ax = plt.subplots(1)

fitsh = []
for i in rmax+rhalf:
    #move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    ax.imshow(frameh)
    bestfit1 = guess_centroid(frameh)
    fitsh.append([bestfit1[0], bestfit1[1], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity
    
    cross = ax.scatter(x=bestfit1[1], y=bestfit1[0], marker='x',
                       color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
    ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
    print(bestfit1)
    ax.set_xlim(800, 1300)
    ax.set_ylim(800, 1300)
# Out:
# (970, 1158)
# (970, 1158)
# (970, 1158)
# (970, 1158)
# (970, 1158)
# (970, 1158)
# (970, 1158)
# (970, 1158)
# (970, 1158)

# %%
coords = ['O','N1', 'S1', 'E1', 'W1', 'N2', 'S2', 'E2', 'W2']
ints = np.array(np.matrix(fitsh).T[2])[0]
plt.style.use('default')
fig, ax = plt.subplots(1)
ax.plot(coords, ints, 'o')

# %%
uInt_sys = np.std(ints)

# %%
uInt_sys
# Out:
# 461.57286117452736

# %% [markdown]
# ##### This is the systematic variation of the maximum intensity

# %% [markdown]
# ### Define whole grid

# %%
xscan = [-2100, -1050, 0, 1050, 2100]
yscan = [-1400, -600, 0, 600, 1400]

# %%
for xx in xscan:
    for yy in yscan:
        move_to_positionXY(serialport, position=[xx, yy], center=center0)
        sleep(0.5)

# %%
move_to_positionXY(serialport, position=[2100, 1400], center=center0)

frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

# %%
# %matplotlib inline
plt.style.use('dark_background')
fig, ax = plt.subplots(1)

fitsh = []
for xx in xscan:
    for yy in yscan:
        move_to_positionXY(serialport, position=[xx, yy], center=center0, wait=2)
    
        frameh = cam0.get_frame(100)
        ax.imshow(frameh)
        bestfit1 = guess_centroid(frameh)
        fitsh.append([bestfit1[0], bestfit1[1], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity

        cross = ax.scatter(x=bestfit1[1], y=bestfit1[0], marker='x',
                           color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
        ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
        print(bestfit1)
        ax.set_xlim(900, 1050)
        ax.set_ylim(900, 1050)
        #ax.set_xlim(1080, 1210)
        #ax.set_ylim(890, 1020)
# Out:
# (936, 1034)
# (1010, 953)
# (989, 955)
# (974, 951)
# (957, 954)
# (936, 951)
# (1011, 970)
# (990, 971)
# (974, 972)
# (951, 971)
# (932, 974)
# (1011, 991)
# (991, 995)
# (974, 992)
# (958, 993)
# (936, 992)
# (1012, 1012)
# (989, 1017)
# (972, 1015)
# (958, 1013)
# (938, 1017)
# (1012, 1037)
# (992, 1038)
# (974, 1033)
# (958, 1033)

# %%
# %matplotlib inline
plt.style.use('dark_background')
fig, ax = plt.subplots(1)

fitsh = []
for xx in xscan:
    for yy in yscan:
        move_to_positionXY(serialport, position=[xx, yy], center=center0)
        sleep(1)

        frameh = cam0.get_frame(100)

        bestfit1 = guessNfitGaussian2d(frameh, flag_p=False)
        fitsh.append(bestfit1)

        plot_fit_result(frameh, bestfit1)
        print(bestfit1[1:3])
plt.gca().set_xlim(800, 1300)
plt.gca().set_ylim(800, 1300)
# Out:
# [770.9660292543838, 486.88922016423726]
# [1120.4410292153302, 987.0928980522428]
# [1118.0425844475521, 969.3371911198387]
# [1117.7772536808807, 949.3884093792867]
# [1118.0690713308823, 922.034724309267]
# [1143.1104307218607, 1011.1956960702544]
# [1139.6053352182305, 989.6839732144015]
# [1139.1338351833642, 970.0193634443551]
# [1139.1857890116012, 949.3270562502383]
# [1139.3790138245981, 921.9194090184584]
# [1163.01554013234, 1012.6953191261617]
# [1160.6879965526439, 990.6807949381753]
# [1160.674684192235, 970.0707940455441]
# [1160.721789461809, 949.4999599103412]
# [1161.0201244327254, 922.0090423013619]
# [1161.0460789709928, 921.9961881255758]
# [1182.5263491329665, 990.8501079588232]
# [1182.4059541314377, 970.2654264220486]
# [1182.4267197617114, 949.481628430788]
# [1182.6022848920777, 921.9804773031185]
# [1204.1556399289002, 1013.8183312852287]
# [1204.2621711605723, 990.9705524357215]
# [1204.2879852446954, 970.1634720866813]
# [1204.192659050809, 949.5157018823911]
# [1204.2966397554897, 922.2290838510767]
# (800, 1300)

# %%
fitsh
# Out:
# [[72.29957073738123,
#   770.9660292543838,
#   486.88922016423726,
#   0.5886787388812265,
#   1.3925157665854462],
#  [21936.676990365897,
#   1120.4410292153302,
#   987.0928980522428,
#   3.8955766611758005,
#   0.004597349508091537],
#  [48192.36234054716,
#   1118.0425844475521,
#   969.3371911198387,
#   5.594482305808167,
#   0.0020948023648302426],
#  [48393.94466567767,
#   1117.7772536808807,
#   949.3884093792867,
#   6.038591948844849,
#   0.0020890752682808807],
#  [46558.759432169994,
#   1118.0690713308823,
#   922.034724309267,
#   5.9190133458942835,
#   0.002172207304220506],
#  [1111.6218696385076,
#   1143.1104307218607,
#   1011.1956960702544,
#   2.175015427938075,
#   0.09061742708933183],
#  [46425.01477355724,
#   1139.6053352182305,
#   989.6839732144015,
#   5.447116655325929,
#   0.0021739123451525026],
#  [46528.07366491717,
#   1139.1338351833642,
#   970.0193634443551,
#   6.299571713721726,
#   0.0021703951412806025],
#  [45810.86628366256,
#   1139.1857890116012,
#   949.3270562502383,
#   6.250295484962896,
#   0.002206061725557614],
#  [47951.35641023878,
#   1139.3790138245981,
#   921.9194090184584,
#   5.981583347123537,
#   0.002108493062214109],
#  [9661.715900402616,
#   1163.01554013234,
#   1012.6953191261617,
#   3.4013126959976177,
#   0.010429866825866194],
#  [45403.96648928003,
#   1160.6879965526439,
#   990.6807949381753,
#   6.372345737827361,
#   0.0022227924128482546],
#  [46866.97851650137,
#   1160.674684192235,
#   970.0707940455441,
#   6.370739212676565,
#   0.0021546006839724802],
#  [45849.620408297604,
#   1160.721789461809,
#   949.4999599103412,
#   6.37960399875751,
#   0.002203837678270139],
#  [44941.04911001115,
#   1161.0201244327254,
#   922.0090423013619,
#   6.164787862037638,
#   0.002250571461493271],
#  [44943.97331677645,
#   1161.0460789709928,
#   921.9961881255758,
#   6.162856566434799,
#   0.0022500483491759006],
#  [43550.20750256424,
#   1182.5263491329665,
#   990.8501079588232,
#   6.66925990017015,
#   0.0023170222577391097],
#  [44076.0679299866,
#   1182.4059541314377,
#   970.2654264220486,
#   6.611173276909976,
#   0.002291069323814035],
#  [42830.3402296104,
#   1182.4267197617114,
#   949.481628430788,
#   6.610305576330658,
#   0.002358613726326299],
#  [43611.50190651533,
#   1182.6022848920777,
#   921.9804773031185,
#   6.328421512338177,
#   0.002317630391383334],
#  [17286.89053309899,
#   1204.1556399289002,
#   1013.8183312852287,
#   4.1273011610124115,
#   0.005829785393491808],
#  [43420.997335226886,
#   1204.2621711605723,
#   990.9705524357215,
#   6.727236436675115,
#   0.002324413597771718],
#  [43539.12933384201,
#   1204.2879852446954,
#   970.1634720866813,
#   6.711968915187081,
#   0.0023200606271289743],
#  [43929.49638269455,
#   1204.192659050809,
#   949.5157018823911,
#   6.634454141982225,
#   0.002300130815170972],
#  [43927.42239466045,
#   1204.2966397554897,
#   922.2290838510767,
#   6.51672150897846,
#   0.0023018803729787005]]

# %%
coords = range(25)
ints = np.array(np.matrix(fitsh).T[0])[0]
waists = np.array(np.matrix(fitsh).T[3])[0]

plt.style.use('default')
fig, ax = plt.subplots(1)
ax.errorbar(x=coords, y=ints, yerr=uInt_sys, fmt='o')
ax.set_ylabel('Intensity')
# Out:
# Text(0, 0.5, 'Intensity')

# %%
fig, ax = plt.subplots(1)
ax.plot(coords, waists,'ro')
ax.set_ylabel('w [px]')
# Out:
# Text(0, 0.5, 'w [px]')

# %% [markdown]
# # Place DM at z = 250 mm from L2, zOb = 0 mm, zCAM = 25 mm, -1 screwhole

# %%
# %matplotlib inline
plt.style.use('dark_background')
fitsh = []
for i in rmax+rhalf:
    move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    
    bestfit1 = guessNfitGaussian2d(frameh, flag_p=False)
    fitsh.append(bestfit1)
    
    plot_fit_result(frameh, bestfit1)
    print(bestfit1[1:3])
fitsHo.append(fitsh)
# Out:
# [1130.6528275720602, 973.8315337450792]
# [1131.082312353736, 890.2575461919563]
# [1129.2410904586993, 1069.866659524316]
# [1071.9041665365307, 975.8108784016713]
# [1032.3126756028746, 973.0225430793241]
# [1130.949967696215, 932.4258616888056]
# [1130.1097039880578, 1020.1092684055577]
# [1130.116689545041, 1020.1461575164103]
# [1083.5815245091746, 973.6019522508573]

# %% [markdown]
# # Microscope scan

# %%
rmax = [(0,0), (0, 2500), (0,-2800), (-4200, 0), (4200, 0)]
rhalf = [(0, 1250), (0, -1400), (-2100, 0), (2100, 0)]
rquart = [(0, 675), (0, -750), (-1050, 0), (1050, 0)]

# %%
move_to_positionXY(serialport, position=rmax[0], center=center0)

# %%
for i in range(25):
    for i in rmax+rhalf:
        move_to_positionXY(serialport, position=i, center=center0, wait=0.1)

# %%
for i in range(25):
    for i in rquart:
        move_to_positionXY(serialport, position=i, center=center0, wait=0.1)

# %%
# %matplotlib inline
frame0 = cam0.get_frame(100)
plt.imshow(frame0)

# %%
frame0
# Out:
# array([[112, 119, 126, ..., 125, 108, 100],
#        [126, 124, 117, ..., 117, 127, 111],
#        [113, 118, 109, ..., 106, 119, 135],
#        ...,
#        [120, 114, 108, ..., 117, 118, 112],
#        [107, 111, 104, ..., 125, 116, 112],
#        [116, 117, 111, ..., 108, 108, 120]], dtype=uint16)

# %%
io.imsave('file_test.tif', frame0)
# Out:
# C:\Users\IFIc\Anaconda3\lib\site-packages\skimage\io\_io.py:141: UserWarning: file_test.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
24/350
# Out:
# 0.06857142857142857

# %%
1.22/1.74
# Out:
# 0.7011494252873564

# %%
#LOOP WITH FOR SAVE IMAGE EVERY 25
#right now error savign io image (quality error?)

# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')
    
for i in range(0,int(1e2),25):
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(1, 1, 1)

    frame0 = cam0.get_frame(100)
    gray = ax1.imshow(frame0, label=frame0.sum()/426104919)
    ax1.set_title(frame0.sum()/426104919)
    fig.colorbar(gray)
    
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    #io.imsave('copy-file'+str(i)+'.tif', frame0)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# %matplotlib notebook
#fig, ax = plt.subplots(2, figsize=(12,12))
fig = plt.figure(figsize=(10,8))
fig.show()
fig.canvas.draw()
plt.style.use('dark_background')

while True:
    
    fig = plt.gcf()
    ax1 = fig.add_subplot(1, 1, 1)

    frame0 = cam0.get_frame(100)
    gray = ax1.imshow(frame0, label=frame0.sum()/426104919)
    ax1.set_title(frame0.sum()/426104919)
    fig.colorbar(gray)
    
    fig.canvas.draw()
    fig.tight_layout()
    #fig.canvas.update()
    fig.canvas.flush_events()
    fig.subplots_adjust(left=0.2, bottom=None, right=0.8, top=None, wspace=0.1, hspace=None)
    plt.clf()     # Clean figure to update legend, barplot...
# Out:
# <img src="data:image/png;base64,..." width="720">
# Exception ignored in: <function TransformNode.set_children.<locals>.<lambda> at 0x000001A859D21DC8>
# Traceback (most recent call last):
#   File "C:\Users\IFIc\Anaconda3\lib\site-packages\matplotlib\transforms.py", line 179, in <lambda>
#     target=child._parents: target.pop(sid))
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-693d2283b92b> in <module>
#      16     fig.colorbar(gray)
#      17
# ---> 18     fig.canvas.draw()
#      19     fig.tight_layout()
#      20     #fig.canvas.update()
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_webagg_core.py in draw(self)
#     149         self._png_is_old = True
#     150         try:
# --> 151             super().draw()
#     152         finally:
#     153             self.manager.refresh_all()  # Swap the frames.
#
# ~\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1707             self.patch.draw(renderer)
#    1708             mimage._draw_list_compositing_images(
# -> 1709                 renderer, self, artists, self.suppressComposite)
#    1710
#    1711             renderer.close_group('figure')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# ~\Anaconda3\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1201         renderer.open_group(__name__)
#    1202
# -> 1203         ticks_to_draw = self._update_ticks()
#    1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _update_ticks(self)
#    1079         major_locs = self.get_majorticklocs()
#    1080         major_labels = self.major.formatter.format_ticks(major_locs)
# -> 1081         major_ticks = self.get_major_ticks(len(major_locs))
#    1082         self.major.formatter.set_locs(major_locs)
#    1083         for tick, loc, label in zip(major_ticks, major_locs, major_labels):
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1412             self.majorTicks.append(tick)
#    1413             tick.gridline.set_visible(self._gridOnMajor)
# -> 1414             self._copy_tick_props(self.majorTicks[0], tick)
#    1415
#    1416         return self.majorTicks[:numticks]
#
# ~\Anaconda3\lib\site-packages\matplotlib\axis.py in _copy_tick_props(self, src, dest)
#    1378         dest.label1.update_from(src.label1)
#    1379         dest.label2.update_from(src.label2)
# -> 1380         dest.tick1line.update_from(src.tick1line)
#    1381         dest.tick2line.update_from(src.tick2line)
#    1382         dest.gridline.update_from(src.gridline)
#
# ~\Anaconda3\lib\site-packages\matplotlib\lines.py in update_from(self, other)
#    1347         self._linestyle = other._linestyle
#    1348         self._marker = MarkerStyle(other._marker.get_marker(),
# -> 1349                                    other._marker.get_fillstyle())
#    1350         self._drawstyle = other._drawstyle
#    1351
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in __init__(self, marker, fillstyle)
#     241         self._marker_function = None
#     242         self.set_fillstyle(fillstyle)
# --> 243         self.set_marker(marker)
#     244
#     245     def _recache(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in set_marker(self, marker)
#     314
#     315         self._marker = marker
# --> 316         self._recache()
#     317
#     318     def get_path(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _recache(self)
#     254         self._capstyle = 'butt'
#     255         self._filled = True
# --> 256         self._marker_function()
#     257
#     258     def __bool__(self):
#
# ~\Anaconda3\lib\site-packages\matplotlib\markers.py in _set_tickdown(self)
#     767
#     768     def _set_tickdown(self):
# --> 769         self._transform = Affine2D().scale(1.0, -1.0)
#     770         self._snap_threshold = 1.0
#     771         self._filled = False
#
# ~\Anaconda3\lib\site-packages\matplotlib\transforms.py in scale(self, sx, sy)
#    1989         scale_mtx = np.array(
#    1990             [[sx, 0.0, 0.0], [0.0, sy, 0.0], [0.0, 0.0, 1.0]], float)
# -> 1991         self._mtx = np.dot(scale_mtx, self._mtx)
#    1992         self.invalidate()
#    1993         return self
#
# KeyboardInterrupt:
# <img src="data:image/png;base64,..." width="720">

# %%
# %matplotlib inline
frameglass = cam0.get_frame(100)
io.imsave('Glass_with_filter.tif', frameglass)
gray = plt.imshow(frameglass)
print('Intensity of glass',frameglass.sum())
plt.colorbar(gray)
# Out:
# Intensity of glass 421966612
# C:\Users\IFIc\Anaconda3\lib\site-packages\skimage\io\_io.py:141: UserWarning: Glass_with_filter.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
# %matplotlib inline
frameglass2 = cam0.get_frame(100)
io.imsave('Glass_with_filter_HP.tif', frameglass2)
gray = plt.imshow(frameglass2)
print('Intensity of glass',frameglass2.sum())
plt.colorbar(gray)
# Out:
# Intensity of glass 421964502
# C:\Users\IFIc\Anaconda3\lib\site-packages\skimage\io\_io.py:141: UserWarning: Glass_with_filter_HP.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
# %matplotlib inline
frameflu = cam0.get_frame(100)
io.imsave('Sample_with_filter.tif', frameflu)
gray = plt.imshow(frameflu)
print('Intensity of sample',frameflu.sum())
plt.colorbar(gray)
# Out:
# Intensity of sample 428463940

# %%
# %matplotlib inline
frameflu2 = cam0.get_frame(100)
io.imsave('Sample_with_filter_HP.tif', frameflu2)
gray = plt.imshow(frameflu2)
print('Intensity of sample',frameflu2.sum())
plt.colorbar(gray)
# Out:
# Intensity of sample 545893885
# C:\Users\IFIc\Anaconda3\lib\site-packages\skimage\io\_io.py:141: UserWarning: Sample_with_filter_HP.tif is a low contrast image
#   warn('%s is a low contrast image' % fname)

# %%
image = plt.imread('Sample_with_filter.tif')
# %matplotlib inline
plt.imshow(image)

# %%
sample_int = frameflu.sum()

bg_int = frameglass.sum()

sample_int/bg_int
# Out:
# 1.0153977300933943

# %%
sample_int_hp = frameflu2.sum()

bg_int_hp = frameglass2.sum()

sample_int_hp/bg_int_hp
# Out:
# 1.293696228978048

# %%
#filter
# %matplotlib inline
frameflu3 = cam0.get_frame(100)
gray = plt.imshow(frameflu3)
plt.colorbar(gray)

# %%
# %matplotlib inline
frameot = cam0.get_frame(100)
gray = plt.imshow(frameot)
plt.colorbar(gray)

# %%
# %matplotlib inline
frameref = cam0.get_frame(100)
gray = plt.imshow(frameref)
plt.colorbar(gray)

# %%
# %matplotlib inline
frameref2 = cam0.get_frame(100)
gray = plt.imshow(frameref2)
plt.colorbar(gray)

# %%
# %matplotlib inline
plt.style.use('default')
gray = plt.imshow(frameref2)
plt.colorbar(gray)

# %%
# %matplotlib inline
plt.style.use('default')
gray = plt.imshow(frameflu2)
plt.colorbar(gray)

# %%
frameref2.sum()
# Out:
# 426104919

# %%
frameflu2.sum()
# Out:
# 426210157

# %%
frameflu2.sum() / frameref2.sum()
# Out:
# 1.0002469767310993

# %%
# %matplotlib inline
plt.style.use('dark_background')
fig, ax = plt.subplots(1)

fitsh = []
for i in rquart:
    move_to_positionXY(serialport, position=i, center=center0)
    sleep(1)
    
    frameh = cam0.get_frame(100)
    ax.imshow(frameh)
    bestfit1 = guess_centroid(frameh)
    fitsh.append([bestfit1[0], bestfit1[1], frameh[bestfit1]]) # For each rmax (xy galvo) store image centroid (x,y) center and intensity
    
    cross = ax.scatter(x=bestfit1[1], y=bestfit1[0], marker='x',
                       color='r', label = '(%.1f, %.1f)' %(bestfit1[0], bestfit1[1]))
    ax.legend([cross], ['(%.1f, %.1f)' %(bestfit1[0], bestfit1[1])])
    print(bestfit1)
    ax.set_xlim(800, 1300)
    ax.set_ylim(800, 1300)
# Out:
# (630, 1476)
# (1428, 1515)
# (1086, 1811)
# (1000, 1100)
