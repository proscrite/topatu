# %%
import pylablib.aux_libs.devices.DCAM as cam
from pylablib.aux_libs.devices.DCAM_lib import lib, DCAMLibError

import matplotlib.pyplot as plt
import sys
sys.path.append('C:\\Users\\IFIc\\Projects\\sabatsw\\laserlab\\scripts')
from galvo_python.galvos import *
from galvo_python.gaussian2dFit import *
from time import sleep

# %% [markdown]
# ## Initialize camera and galvos

# %%
serialport = open_serial_port()

# %%
cam.get_cameras_number(), cam.DCAMCamera(0).get_model_data()
# Out:
# (1,
#  ModelData(vendor='Hamamatsu', model='C13440-20C', serial_number='S/N: 303065', camera_version='4.31.B'))

# %%
cam0 = cam.DCAMCamera(0)
lib.dcamapi_uninit()     # For some reason this must be run before opening the camera
cam0.open()

# %%
cam0.start_acquisition()
cam0.get_status()
# Out:
# 'busy'

# %%
cam0.stop_acquisition()

# %% [markdown]
# #  Take snap

# %%
center0 = [int(65534./2)+1100 ,int(65534./2)+5950]#calibrated on 29/01/2020
move_to_positionXY(serialport, [-2000,-9000], center=center0)
frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

# %% [markdown]
# ## Realigning without lenses, with 2 pinholes

# %% [markdown]
# The procedure is the following:
#
# - Use the first aligning mirror to direct the spot to the center of both galvo mirrors
# - Use the second aligning mirror to focus it through the first pinhole
# - To make the spot pass through the second pinhole, play with the second aligning mirror, the rotation of the galvos (not the position, just for large adjustment) and the origin of the galvos rotation (center0) for fine tuning.

# %%
center0 = [int(65534./2) + 5800, int(65534./2) +  4850] #calibrated on 12/05/2020
move_to_positionXY(serialport, [0,0], center=center0)

# %%
move_to_positionXY(serialport, [0,200], center=center0)
frame = cam0.get_frame(100)

gray = plt.imshow(frame)
plt.colorbar(gray)

# %%
guessNfitGaussian2d(frame)
# Out:
# (434,) [0, 934]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-109-ee8263fd409d> in <module>
# ----> 1 guessNfitGaussian2d(frame)
#
# ~\Projects\laserlab\scripts\galvo_python\gaussian2dFit.py in guessNfitGaussian2d(im, DEBUG, flag_p)
#     134     bounds = bound_roi(img, mx, 500)
#     135     print(mx, bounds)
# --> 136     imroi = select_roi(img, bounds)
#     137
#     138     mxroi = guess_centroid(imroi)
#
# ~\Projects\laserlab\scripts\galvo_python\gaussian2dFit.py in select_roi(im, bounds)
#      27
#      28 def select_roi(im : np.ndarray, bounds : list) -> np.ndarray:
# ---> 29     return im[bounds[0] : bounds[1], bounds[2] : bounds[3]]
#      30
#      31 def plot_fit_result(im : np.ndarray, p0 : list, ax = None):
#
# IndexError: list index out of range

# %%
plt.imshow(rgb2gray(frame))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-111-1fa0f7de0280> in <module>
# ----> 1 plt.imshow(rgb2gray(frame))
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2681         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2682         resample=resample, url=url, **({"data": data} if data is not
# -> 2683         None else {}), **kwargs)
#    2684     sci(__ret)
#    2685     return __ret
#
# ~\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     367                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     368                 f"should be pass as keyword, not positionally.")
# --> 369         return func(*args, **kwargs)
#     370
#     371     return wrapper
#
# ~\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, **kwargs)
#    5669                               resample=resample, **kwargs)
#    5670
# -> 5671         im.set_data(X)
#    5672         im.set_alpha(alpha)
#    5673         if im.get_clip_path() is None:
#
# ~\Anaconda3\lib\site-packages\matplotlib\image.py in set_data(self, A)
#     688                 or self._A.ndim == 3 and self._A.shape[-1] in [3, 4]):
#     689             raise TypeError("Invalid shape {} for image data"
# --> 690                             .format(self._A.shape))
#     691
#     692         if self._A.ndim == 3:
#
# TypeError: Invalid shape (2048,) for image data

# %%
guess_centroid(rgb2gray(frame))
# Out:
# (434,)
